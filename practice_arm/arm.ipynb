# %%
# !pip install autograd
# Out:
# Requirement already satisfied: autograd in /Users/barnrang/miniconda3/envs/liigo/lib/python3.6/site-packages (1.3)
# Requirement already satisfied: numpy>=1.12 in /Users/barnrang/miniconda3/envs/liigo/lib/python3.6/site-packages (from autograd) (1.17.4)
# Requirement already satisfied: future>=0.15.2 in /Users/barnrang/miniconda3/envs/liigo/lib/python3.6/site-packages (from autograd) (0.18.2)
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import functools 

import autograd.numpy as np
from autograd import grad, jacobian
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import HTML

from arms import TwoArmModel, ThreeArmModel

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
arm = ThreeArmModel()

arm.get_pos()
# Out:
# array([-1.2246468e-16,  1.2246468e-16,  3.0000000e+00])

# %%
arm.set_angle(np.pi/3, np.pi/5)

arm.get_pos()
# Out:
# array([ 1.14647789, -0.66191932,  1.13209351])

# %%
arm.update_reverse_kinematic(0.4, 1.2, 1.8, MAX=1000)
# Out:
# Found angles! theta_1 = 2.8198420995169866 theta_2 = 0.28160046215897605 theta_3 = 1.4505064535349683

# %%
arm.get_pos()
# Out:
# array([0.4       , 1.2       , 1.79999999])

# %%
fig = plt.figure()
ax = Axes3D(fig)
