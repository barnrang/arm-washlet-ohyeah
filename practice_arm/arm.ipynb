# %%
# !pip install autograd
# !conda install -y -c conda-forge ffmpeg
# Out:
# ...
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import functools 

import autograd.numpy as np
from autograd import grad, jacobian
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
from IPython.display import HTML

from arms import TwoArmModel, ThreeArmModel

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
arm = ThreeArmModel()

arm.get_pos()
# Out:
# array([-1.2246468e-16,  1.2246468e-16,  3.0000000e+00])

# %%
arm.set_angle(np.pi/3, np.pi/5)

arm.get_pos()
# Out:
# array([ 1.01807392, -0.58778525,  2.61803399])

# %%
arm.update_reverse_kinematic(0.6, 1.2, 0.5, MAX=1000)

arm.get_pos()
# Out:
# Found angles! theta_1 = 2.6779451090927333 theta_2 = 1.154632569766795 theta_3 = 1.5457940244668809
# array([0.59999986, 1.19999992, 0.50000025])

# %%
arm.update_reverse_kinematic(1.6, 0.2, 1.8, MAX=1000)

arm.get_pos()
# Out:
# Found angles! theta_1 = 1.695151324929654 theta_2 = 0.6592154739109848 theta_3 = 0.9020537199905441
# array([1.59999996, 0.2       , 1.79999998])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlim(0,2)
ax.set_ylim(0,2)
ax.set_zlim(0,2)

lines = arm.plot_arm(ax)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlim(0,2)
ax.set_ylim(0,2)
ax.set_zlim(0,2)

arm.update_reverse_kinematic(0.6, 1.2, 0.5, MAX=1000)

anim = arm.plot_reverse_animation(fig, ax, 1.6, 0.2, 1.8, MAX=1000)
# Out:
# Found angles! theta_1 = 2.6779432616290233 theta_2 = 1.1546312512801427 theta_3 = 1.545797060830603
# Found angles! theta_1 = 1.6951513224785675 theta_2 = 0.6592154351244268 theta_3 = 0.9020538083973246
# [1.59999993 0.19999999 1.79999996]

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
