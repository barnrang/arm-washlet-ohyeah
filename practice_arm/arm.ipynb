# %%
# !pip install autograd
# !conda install -y -c conda-forge ffmpeg
# Out:
# Requirement already satisfied: autograd in /Users/barnrang/miniconda3/envs/liigo/lib/python3.6/site-packages (1.3)
# Requirement already satisfied: numpy>=1.12 in /Users/barnrang/miniconda3/envs/liigo/lib/python3.6/site-packages (from autograd) (1.17.4)
# Requirement already satisfied: future>=0.15.2 in /Users/barnrang/miniconda3/envs/liigo/lib/python3.6/site-packages (from autograd) (0.18.2)
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import functools 

import autograd.numpy as np
from autograd import grad, jacobian
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
from IPython.display import HTML

from arms import ThreeArmModel

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
arm = ThreeArmModel()

arm.get_pos()
# Out:
# array([-1.2246468e-16,  1.2246468e-16,  3.0000000e+00])

# %%
arm.set_angle(np.pi/3, np.pi/5)

arm.get_pos()
# Out:
# array([ 1.01807392, -0.58778525,  2.61803399])

# %%
arm.update_reverse_kinematic(0.6, 1.2, 0.5, MAX=1000)

arm.get_pos()
# Out:
# Found angles! theta_1 = 2.6779449149291565 theta_2 = 1.154632800747672 theta_3 = 1.5457953339408448
# array([0.59999952, 1.19999864, 0.49999938])

# %%
arm.update_reverse_kinematic(1.6, 0.2, 1.8, MAX=1000)

arm.get_pos()
# Out:
# Found angles! theta_1 = 1.6951513231614523 theta_2 = 1.5612691702846497 theta_3 = 5.3811316363096555
# array([1.59999998, 0.2       , 1.79999999])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlim(0,2)
ax.set_ylim(0,2)
ax.set_zlim(0,2)

lines = arm.plot_arm(ax)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlim(0,2)
ax.set_ylim(0,2)
ax.set_zlim(0,2)

arm.update_reverse_kinematic(0., 0., 3.0, MAX=1000)

anim = arm.plot_reverse_animation(fig, ax, 1.1, 0.3, 2.1, MAX=1000)
# Out:
# Found angles! theta_1 = 5.541238035386318 theta_2 = 0.01894175070954507 theta_3 = 6.245301805782317
# Found angles! theta_1 = 1.8370483760066136 theta_2 = 1.4598046103035118 theta_3 = 4.970236666217353

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
